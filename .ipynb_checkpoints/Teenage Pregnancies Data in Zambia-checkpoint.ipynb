# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('Teen pregnancies in Zambia.csv')

# %%
data = pd.read_csv('Teen pregnancies in Zambia.csv')

# %%
data
# Out:
#      YearOfConception       Province  Terminations  Deliveries  Pregnancies
# 0                1994         LUSAKA            32          73          105
# 1                1994        LUAPULA             2          12           14
# 2                1994  COPPERBELT005            31          67           98
# 3                1994       SOUTHERN            62         155          217
# 4                1994        EASTERN           130         260          390
# ..                ...            ...           ...         ...          ...
# 265              2020       NORTHERN            34          31           65
# 266              2020        WESTERN            31          12           43
# 267              2020        CENTRAL            39          49           88
# 268              2020  NORTH WESTERN            45          75          120
# 269              2020       MUCHINGA            12          21           33
#
# [270 rows x 5 columns]

# %%
lua = data[data.Province == 'LUAPULA']

# %%
lua
# Out:
#      YearOfConception Province  Terminations  Deliveries  Pregnancies
# 1                1994  LUAPULA             2          12           14
# 11               1995  LUAPULA             2           6            8
# 21               1996  LUAPULA             5           3            8
# 31               1997  LUAPULA             5           1            6
# 41               1998  LUAPULA             8           0            8
# 51               1999  LUAPULA             6           0            6
# 61               2000  LUAPULA             2           1            3
# 71               2001  LUAPULA             5           0            5
# 81               2002  LUAPULA             3           0            3
# 91               2003  LUAPULA             3           1            4
# 101              2004  LUAPULA             4           1            5
# 111              2005  LUAPULA            10           0           10
# ...

# %%
lsk = data[data.Province == 'LUSAKA']

# %%
plt.plot(lua.YearOfConception, lua.Pregnancies)
plt.plot(lsk.YearOfConception, lsk.Pregnancies)
plt.legend(['Luapula', 'Lusaka'])
plt.xlabel('Year')
plt.ylabel('No. of pregnancies')
plt.show()

# %%
lua.Pregnancies
# Out:
# 1       14
# 11       8
# 21       8
# 31       6
# 41       8
# 51       6
# 61       3
# 71       5
# 81       3
# 91       4
# 101      5
# 111     10
# 121      8
# 131     13
# 141      7
# 151      7
# 161     57
# 171    163
# 181      6
# 191      8
# 201      3
# 211    143
# 221      1
# 231      3
# 241      1
# 251     93
# 261      1
# Name: Pregnancies, dtype: int64

# %%
lua.Pregnancies / lua.Pregnancies.iloc[0] * 100
# Out:
# 1       100.000000
# 11       57.142857
# 21       57.142857
# 31       42.857143
# 41       57.142857
# 51       42.857143
# 61       21.428571
# 71       35.714286
# 81       21.428571
# 91       28.571429
# 101      35.714286
# 111      71.428571
# 121      57.142857
# 131      92.857143
# 141      50.000000
# 151      50.000000
# 161     407.142857
# 171    1164.285714
# 181      42.857143
# 191      57.142857
# 201      21.428571
# 211    1021.428571
# 221       7.142857
# 231      21.428571
# 241       7.142857
# 251     664.285714
# 261       7.142857
# Name: Pregnancies, dtype: float64

# %%
plt.plot(lua.YearOfConception, lua.Pregnancies / lua.Pregnancies.iloc[0] * 100)
plt.plot(lsk.YearOfConception, lsk.Pregnancies / lsk.Pregnancies.iloc[0] * 100)
plt.legend(['Luapula', 'Lusaka'])
plt.xlabel('Year')
plt.ylabel('Rise in Pregnancies(first year = 100)')
plt.show()
